# %%
print("Hello, World!")
print("Welcome to Python programming.")
# Out:
# Hello, World!
# Welcome to Python programming.

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.14.5 (main, May 11 2026, 00:00:00) [GCC 16.1.1 20260501 (Red Hat 16.1.1-1)]
