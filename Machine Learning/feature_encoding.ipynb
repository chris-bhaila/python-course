# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"/home/chris/Documents/Broadway Python/Lesson 1/Machine Learning/feature_scaling_encoding.csv")

# %%
df.head()
# Out:
#   CustomerID  Age      Gender Education_Level  Annual_Income  Credit_Score  \
# 0  CUST_0001   56  Non-binary          Master   48747.730343           595
# 1  CUST_0002   69  Non-binary        Bachelor  105564.974064           535
# 2  CUST_0003   46  Non-binary        Bachelor   34241.052210           355
# 3  CUST_0004   32        Male             PhD   20000.000000           659
# 4  CUST_0005   60  Non-binary     High School   79253.378392           409
#
#   City_Category Satisfaction_Level Employment_Status  Experience_Years  \
# 0        Tier 1     Very Satisfied        Unemployed                38
# 1        Tier 2            Neutral          Employed                40
# 2        Tier 3       Dissatisfied     Self-Employed                25
# 3        Tier 2            Neutral        Unemployed                12
# 4        Tier 2  Very Dissatisfied          Employed                39
#
#   Product_Preference Subscription_Plan  Distance_from_Store  \
# ...

# %%
df.describe()
# Out:
#               Age  Annual_Income  Credit_Score  Experience_Years  \
# count  1000.00000    1000.000000   1000.000000       1000.000000
# mean     43.81900   61287.422704    577.375000         23.033000
# std      14.99103   19555.489805    156.064604         13.601504
# min      18.00000   20000.000000    300.000000          0.000000
# 25%      31.00000   47654.741864    445.000000         11.000000
# 50%      44.00000   61826.283435    577.000000         24.000000
# 75%      56.00000   74812.507748    719.250000         36.250000
# max      69.00000  129917.555792    849.000000         40.000000
#
#        Distance_from_Store  Number_of_Purchases
# count          1000.000000          1000.000000
# mean              4.973256             9.938000
# std               4.928758             3.043258
# min               0.100000             2.000000
# 25%               1.507981             8.000000
# 50%               3.584687            10.000000
# ...

# %%
# ── Visualize original distributions ─────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 8))
axes = axes.flatten()

all_columns = ['Age', 'Annual_Income', 'Credit_Score', 'Experience_Years', 'Distance_from_Store', 'Number_of_Purchases']

for i, col in enumerate(all_columns):
    axes[i].boxplot(df[col], vert=True)
    axes[i].set_title(f'{col}\n(Original)', fontsize=12)
    axes[i].set_ylabel('Value')

fig.suptitle("Original Data — Box Plots (Notice the different scales!)", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6681/1556134818.py:8: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axes[i].boxplot(df[col], vert=True)
# /tmp/ipykernel_6681/1556134818.py:8: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axes[i].boxplot(df[col], vert=True)
# /tmp/ipykernel_6681/1556134818.py:8: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axes[i].boxplot(df[col], vert=True)
# /tmp/ipykernel_6681/1556134818.py:8: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axes[i].boxplot(df[col], vert=True)
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder

standard_cols = ['Age', 'Credit_Score', 'Experience_Years']
robust_cols = ['Annual_Income', 'Distance_from_Store', 'Number_of_Purchases']
