# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib64/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in ./venv/lib64/python3.14/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib64/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Creating series with list
l = [1,2,3,4,5]
s = pd.Series(l)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s = pd.Series(l, index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import numpy as np

a = np.array([10,50,20])
pd.Series(a)
# Out:
# 0    10
# 1    50
# 2    20
# dtype: int64

# %%
#Creating Series with Dictionary
d={'name':'miraj','roll':10,'age':15}
s=pd.Series(d)
s
# Out:
# name    miraj
# roll       10
# age        15
# dtype: object

# %%
a = pd.Series([1,2,3])
b = pd.Series([2,3,4])
a+b # Adds elements at [index] of the series ///Doesn't concat
# Out:
# 0    3
# 1    5
# 2    7
# dtype: int64

# %%
#making data frame by reading excel
df=pd.read_excel(r"/home/chris/Documents/Broadway Python/Lesson 2/archive/pandas_data/excel_df.xlsx")
df
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
# Making data frame by reading csv
df=pd.read_csv(r"/home/chris/Documents/Broadway Python/Lesson 2/archive/pandas_data/new_data.csv")
df
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
dict = {'name': ['miraj', 'sabal', 'sarita', 'rashmi', 'sabnam'],
        'roll': [1, 2, 3, 4, 5], 'age': [13, 34, 32, 54, 32],}
df = pd.DataFrame(dict, index=['a','b','c','d','e'])
df
# Out:
#      name  roll  age
# a   miraj     1   13
# b   sabal     2   34
# c  sarita     3   32
# d  rashmi     4   54
# e  sabnam     5   32

# %%
df.at['a', 'name']
# Out:
# 'miraj'

# %%
df.at['d','name']
# Out:
# 'rashmi'

# %%
df.iat[3, 0] # Row by Column
# Out:
# 'rashmi'

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
df.axes[1]
# Out:
# Index(['name', 'roll', 'age'], dtype='str')

# %%
df.columns
# Out:
# Index(['name', 'roll', 'age'], dtype='str')

# %%
df.dtypes
# Out:
# name      str
# roll    int64
# age     int64
# dtype: object

# %%
df['name']
# Out:
# a     miraj
# b     sabal
# c    sarita
# d    rashmi
# e    sabnam
# Name: name, dtype: str

# %%
df['age'].value_counts()
# Out:
# age
# 32    2
# 13    1
# 34    1
# 54    1
# Name: count, dtype: int64

# %%
df.to_dict()
# Out:
# {'name': {'a': 'miraj',
#   'b': 'sabal',
#   'c': 'sarita',
#   'd': 'rashmi',
#   'e': 'sabnam'},
#  'roll': {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5},
#  'age': {'a': 13, 'b': 34, 'c': 32, 'd': 54, 'e': 32}}

# %%
df.to_json('new.json', indent=4)

# %%
df.sort_index(ascending=False)
# Out:
#      name  roll  age
# e  sabnam     5   32
# d  rashmi     4   54
# c  sarita     3   32
# b   sabal     2   34
# a   miraj     1   13

# %%
df.set_index('roll')
# Out:
#         name  age
# roll
# 1      miraj   13
# 2      sabal   34
# 3     sarita   32
# 4     rashmi   54
# 5     sabnam   32

# %%
df.reset_index()
# Out:
#   index    name  roll  age
# 0     a   miraj     1   13
# 1     b   sabal     2   34
# 2     c  sarita     3   32
# 3     d  rashmi     4   54
# 4     e  sabnam     5   32

# %%
df.reset_index(drop=True)
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
import numpy as np
import pandas as pd

data = {'Name': ['John', 'Emma', np.nan],
'Age': [25, np.nan, 30],
'Height': [175, 162, np.nan]}
df = pd.DataFrame(data)
df
# Out:
#    Name   Age  Height
# 0  John  25.0   175.0
# 1  Emma   NaN   162.0
# 2   NaN  30.0     NaN

# %%
df.replace(np.nan, None, inplace=True)
# Out:
#    Name   Age Height
# 0  John  25.0  175.0
# 1  Emma  None  162.0
# 2   NaN  30.0   None
